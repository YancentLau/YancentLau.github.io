# %% [markdown]
# # Task 2 : Open the door (Normal)
# ## Multi-Steps
#
# ![Task 2 Image](Task_2.png)
#
# ![Task 2 Door Image](Task_2_Door.png)
#
# In this task, your agent robot need to follow the blue track and step on the button at the end of track. But this time will be a bit harder then Task 1.
#
# As you can see, there is a door in the middle of the blue track, your agent robot need to press the button right in front of you and bypass that door fast enough.
#
# To archieve it, you may need to finish the whole program and run it instead of run the command one by one.

# %% [markdown]
# # Map for Agent Robot
#
# ![Task 2 Map Image](Task_2_Map.png)
#
# Here is the map for Agent Robot, Hope that it can help you to finish the mission

# %% [markdown]
# # Now is your time !

# %%
# Code Here!
