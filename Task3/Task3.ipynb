# %% [markdown]
# # Task 3 : The Final Task (Hard)
# ## Cooperation
#
# ![Task 3 Image](Task_3.png)
#
#
# This is your final mission. Same as task 2, your agent robot need to follow the blue track and open the door for you to get to the end point of this maze.

# %% [markdown]
# # Map for Agent Robot
#
# ![Task 3 Map Image](Task_3_Map.png)
#
# ## Outside Door
# As you can see, there is a door next to you and on top of the green bricks. There is also a button on the green bricks which only your agent robot can passes through and press it. So that you can bypass that door.
#
#
#
# ## Inside Door
# ![Task 3 inside door Image](Task_3_InsideDoor.png)
#
# After that, there is a button with yellow bricks in front of you, you can open the door in yello bricks for your agent by pressing this button.
#
# ## Final Gate
# Finally, you will see a blue bricks which blocked your way to pass through. When your agent press the button which placed at the end of the track, the blue bricks will be lower.
#
# ![Task 3 lower bricks Image](Task_3_LowerBricks.png)

# %% [markdown]
# # Now is your time !

# %%
# Code Here!
