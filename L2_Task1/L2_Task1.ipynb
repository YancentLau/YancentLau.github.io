# %% [markdown]
# # Task 1 : Choose the right door (Easy)
# ## Agent Detection
# ![L2 Task 1 main Image](L2_Task_1_main.png)
#
#
# Welcome to Level 2. You will face some whole new challenges.
# Let see can you still finish it!~
#
# As you can see in the picture, there are six doors for you to leave this room.
# But only one of it is the right one, you can figure out the answer by getting into the path right next to the npc.

# %% [markdown]
# ## Agent Inspect
# ![L2 Task 1 road Image](L2_Task_1_agentroad.png)
# Inside the path for agent, there are a block with a special material.
# ![L2 Task 1 block name Image](L2_Task_1_blockname.png)
# There are 6 different material will spawn on it randomly, including : ```
#    1. smooth_stone
#    2. gold_block
#    3. iron_block
#    4. copper_block
#    5. emerald_block
#    6. diamond_block
# ```
# You can control your agent to detect it by the following command.

# %%
agent.inspect("down")

# %% [markdown]
# This function will return the name of material under your agent.
# You can also detect other directions of your abent b l:
# ```
#    agent.inspect("back")
#    agent.inspect("left")
#    agent.inspect("right")
# ```

# %% [markdown]
# # Agent Say
#
# As you see, your agent robot will move a step forward by command
# ```
# agent.move("forward")
# ```
# When you need to move few more step, it is better to use for loop to instead of copying a same code.
#
# ```
# for i in range (3):
#    agent.move("forward")
# ```
# What we have here
# - <b>for (variable) in range (looping time):</b> the variable will loop inside the range that you set.
# - Let's talk about the previous example
# - &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; it means code inside for loop will loop for <b>3</b> times
# - &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; </b>i</b> will become 0 in the first loop
# - &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; </b>i</b> will become 1 in the second loop
# - &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; </b>i</b> will become 2 in the third loop
# - So this for loop will order your agent robot to move forward by three times.

# %% [markdown]
# # Now is your time !

# %%
# Code Here!
