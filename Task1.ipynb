# %% [markdown]
# # Task 1 : Open the door
# ## Walk by for loop
#
# ![Task 1 Image](Task_1.png)
#
# ![Task 1 Door Image](Task_1_Door.png)
#
# In this maze, you need to open the gate by pressing the button in front of you. But there are some limitation, only your agent is short enough to go in this area.
#
# To continous your mission, you may need to coding the agent robot to walk forward and step on the button
#
#
# What we have here:
# 1. Guide the agent robot to move one step forward

# %%
agent.move("forward")

# %% [markdown]
# If you need to move to different directions, you can try :
# ```
#    agent.move("back")
#    agent.move("left")
#    agent.move("right")
# ```

# %% [markdown]
# # For Loop
#
# As you see, your agent robot will move a step forward by command
# ```
# agent.move("forward")
# ```
# When you need to move few more step, it is better to use for loop to instead of copying a same code.
#
# ```
# for i in range (3):
#    agent.move("forward")
# ```
# What we have here
# - <b>for (variable) in range (looping time):</b> the variable will loop inside the range that you set.
# - Let's talk about the previous example
# - &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; it means code inside for loop will loop for <b>3</b> times
# - &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; </b>i</b> will become 0 in the first loop
# - &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; </b>i</b> will become 1 in the second loop
# - &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; </b>i</b> will become 2 in the third loop
# - So this for loop will order your agent robot to move forward by three times.

# %% [markdown]
# # Now is your time !

# %%
# Code Here!
